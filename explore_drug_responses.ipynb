# %%
import pandas as pd

# %%
df = pd.read_csv('data/DrugResponse.csv', index_col=0, sep=",") #61 rows × 101 columns
df = df.dropna() #27 rows × 101 columns
df
# Out:
#                                                     MM013  MM014  MM015  \
# Bendamustine_DNA-alkylating agent                   -0.10  -0.05  -0.23
# Bortezomib_Proteasome Inhibitor regime               0.34   0.45   0.65
# Carfilzomib_Proteasome Inhibitor regime              0.48   0.57   0.66
# Cisplatin_Platinum-containing                       -0.17  -0.16  -0.27
# Cyclophosphamide_DNA-alkylating agent               -0.15   0.03  -0.05
# Cytarabine_Nucleoitide analog                        0.19  -0.10  -0.13
# Dexamethasone_Corticosteroid                        -0.10   0.45   0.19
# Etoposide_Topoisomerase inhibitor                    0.12  -0.08   0.16
# Ixazomib_Proteasome Inhibitor regime                 0.22   0.23   0.62
# Lenalidomide_Corticosteroid + IMID                  -0.09   0.17  -0.03
# Melphalan_DNA-alkylating agent                      -0.26  -0.15  -0.22
# Panobinostat_HDACi                                  -1.04   0.10   0.02
# ...

# %%
# Define the function to plot the distribution

plt.figure(figsize=(10, 6))
row_data = df.iloc[0]
plt.hist(row_data, bins=5, alpha=0.7, color='blue')
plt.title(f'Distribution of Row {0}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
